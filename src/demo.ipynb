# %% [markdown]
# Reference: https://www.metagenomics.wiki/tools/fastq/ncbi-ftp-genome-download

# %%
import importlib
import MicroRG as mrg
importlib.reload(mrg)
# Out:
# <module 'MicroRG' from '/grain/wl61/github/MicroRG/src/MicroRG.py'>

# %% [markdown]
# **Initialization**
#
# When you create an `MicroRG` object, it will automatically detect and download the assembly summary report if you don't have the report at the current working directory.

# %%
microbe_rg = mrg.MicroRG()

# %% [markdown]
# **Query**
#
# Take fly (Drosophila melanogaster) as an example.

# %%
results = microbe_rg.search(["Drosophila melanogaster"])
# Out:
# Search results: 1 / 1
# Number of strain: 1
# Number of unfound species: 0

# %%
results
# Out:
# ({'drosophila melanogaster': [('',
#     'https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/001/215/GCF_000001215.4_Release_6_plus_ISO1_MT')]},
#  [])

# %% [markdown]
# **Example**

# %%
import pandas as pd

# %%
dir_file = "/grain/wl61/github/cancer_microbiome/data/genome_coverage/sp_list/sp_list.txt"
df_sp = pd.read_csv(dir_file, sep="\t")
df_sp.head()
# Out:
#           D               P              C              O               F  \
# 0  Bacteria  Actinobacteria  Actinomycetia  Micrococcales  Micrococcaceae
# 1  Bacteria  Actinobacteria  Actinomycetia  Micrococcales  Micrococcaceae
# 2  Bacteria  Actinobacteria  Actinomycetia  Micrococcales  Micrococcaceae
# 3  Bacteria  Actinobacteria  Actinomycetia  Micrococcales  Micrococcaceae
# 4  Bacteria  Actinobacteria  Actinomycetia  Micrococcales  Micrococcaceae
#
#         G                    S
# 0  Rothia  Rothia mucilaginosa
# 1  Rothia  Rothia dentocariosa
# 2  Rothia         Rothia aeria
# 3  Rothia     Rothia kristinae
# 4  Rothia    Rothia nasimurium

# %%
species = list(df_sp["S"])

# %%
results, unfound = microbe_rg.search(species, full_genome=True, strain_specific=False)
# Out:
# Search results: 5831 / 7927
# Number of strain: 180072
# Number of unfound species: 2096

# %%
unfound
# Out:
# ['pseudomonas virus ab09',
#  'lactococcus virus ascc532',
#  'blautia sp. lzlj-3',
#  'citrobacter virus sh3',
#  'alkalihalobacillus pseudofirmus',
#  'klebsiella virus zckp1',
#  'escherichia virus f',
#  'culex pipiens associated tunisia virus',
#  'geobacillus sp. 44c',
#  'nocardiopsis sp. 90127',
#  'tetragenococcus muriaticus',
#  'klebsiella sp. wp8-s18-esbl-06',
#  'vibrio sp. sm1977',
#  'nerine yellow stripe virus',
#  'solitalea canadensis',
#  'actinoplanes friuliensis',
#  'bacillus vini',
#  'spiroplasma taiwanense',
#  'desulfopila sp. imcc35004',
#  'gordonia virus wizard',
#  'desulfotalea psychrophila',
#  'bat hp-betacoronavirus zhejiang2013',
#  'oscillibacter sp. nsj-62',
#  'pseudomonas virus pakp1',
#  'acholeplasma brassicae',
#  'mycobacterium virus angelica',
#  'filifactor alocis',
#  'thermodesulfobium narugense',
#  'phenylobacterium zucineum',
#  'maridesulfovibrio hydrothermalis',
#  'arthrobacter virus arv1',
#  'gordonia virus ruthy',
#  'escherichia virus biff',
#  'mycobacterium virus gadjet',
#  'mycobacterium virus lukilu',
#  'mycobacterium virus d29',
#  'main drain orthobunyavirus',
#  'burkholderia sp. ccge1003',
#  'citrobacter sp. rhbstw-00881',
#  'rahnella sp. wmr66',
#  'mycoplasma edwardii',
#  'enterococcus virus ef24c',
#  'sulfolobus islandicus rod-shaped virus 10',
#  'rickettsia akari',
#  'mycolicibacterium sp. z-34',
#  'desulfovibrio magneticus',
#  'neorickettsia risticii',
#  'hahella chejuensis',
#  'isoptericola dokdonensis',
#  'mycobacterium virus u2',
#  'kangiella koreensis',
#  'anaplasma ovis',
#  'pseudomonas virus el',
#  'lancefieldella parvula',
#  'tenacibaculum sp. dsm 106434',
#  'escherichia virus ga2a',
#  'pseudomonas virus pmbt3',
#  'erwinia virus simmy50',
#  'streptococcus virus cp7',
#  'aeromonas virus asgz',
#  'komagataeibacter hansenii',
#  'staphylococcus virus sch1',
#  'mycoplasma sp. zaradi2',
#  'zucchini lethal chlorosis orthotospovirus',
#  'pseudomonas virus vcm',
#  'mycobacterium sp. elw1',
#  'sphingomonas sp. c8-2',
#  'human polyomavirus 10',
#  'salmonella virus stg2',
#  'pseudomonas virus dl68',
#  'pseudomonas virus pf1 erz-2017',
#  'gloeobacter kilaueensis',
#  'gloeomargarita lithophora',
#  'propionibacterium virus phl113m01',
#  'streptomyces fulvissimus',
#  'mycobacterium virus bbpiebs31',
#  'effusibacillus sp. skt53',
#  'streptomyces sp. gba 94-10',
#  'sphingomonas sp. sh',
#  'halomonas sp. mccc 1a11059',
#  'streptomyces sp. f8',
#  'labrenzia sp. cp4',
#  'shigella virus sf14',
#  'caulobacter virus ccrpw',
#  'weissella cryptocerci',
#  'shigella sp. pamc 28760',
#  'mycobacterium virus zemanar',
#  'bacillus virus bobb',
#  'bacillus horikoshii',
#  'synechococcus elongatus',
#  'enterococcus virus phishef4',
#  'fulvivirga sp. s481',
#  'erwinia virus ea2809',
#  'simian mastadenovirus g',
#  'kirsten murine sarcoma virus',
#  'stanieria cyanosphaera',
#  'propionibacterium virus phl116m00',
#  'sphingomonas wittichii',
#  'lactobacillus sp.',
#  'gammapapillomavirus 6',
#  'spiroplasma phoeniceum',
#  'mycobacterium virus che12',
#  'desulfomicrobium baculatum',
#  'streptococcus virus sfi11',
#  'burkholderia sp. bdu6',
#  'citrobacter sp. rhbstw-00696',
#  'streptomyces davaonensis',
#  'propionibacterium virus phl132n00',
#  'erwinia virus ea35-70',
#  'hepatovirus h',
#  'pseudomonas virus 119x',
#  'arthrobacter virus mudcat',
#  'thermodesulfatator indicus',
#  'lycoris mild mottle virus',
#  'alphapapillomavirus 13',
#  'enterococcus virus eflk1',
#  'dickeya virus ad1',
#  'aminobacterium colombiense',
#  'escherichia virus cf2',
#  'rahnella sp. y9602',
#  'arthrobacter virus preamble',
#  'spirochaeta africana',
#  'sphingomonas sp. sand1-3',
#  'lactococcus virus cb20',
#  'lactococcus virus cb14',
#  'mastomys natalensis polyomavirus 1',
#  'gracilibacillus sp. scu50',
#  'halomonas sp. mccc 1a13718',
#  'escherichia virus ayo145a',
#  'dokdonella koreensis',
#  'escherichia virus jenp1',
#  'escherichia virus slur04',
#  'arthrobacter virus hunterdalle',
#  'mycobacterium virus che9c',
#  'haliangium ochraceum',
#  'streptomyces virus mildred21',
#  'winkia sp. c64',
#  'enterococcus virus ef3',
#  'caulobacter virus ccrcolossus',
#  'enterobacter sp. rfl1396',
#  'shigella virus sf13',
#  'citrobacter freundii complex sp. cfnih4',
#  'pseudomonas sp. k-62',
#  'synechococcus virus scam1',
#  'pseudomonas virus 73',
#  'salmonella sp.',
#  'mycobacterium virus redrock',
#  'microbacterium virus robsfeet',
#  'salmonella virus sp3',
#  'escherichia virus vec33',
#  'arthrobacter virus shade',
#  'dactylococcopsis salina',
#  'sphingomonas sp. xs-10',
#  'escherichia virus apcec01',
#  'xanthomonas virus op2',
#  'gammapapillomavirus 11',
#  'dehalogenimonas sp. gp',
#  'klebsiella virus kp36',
#  'oscillibacter sp. pea192',
#  'ottowia sp. 27c',
#  'escherichia virus t4',
#  'zea mosaic virus',
#  'acidothermus cellulolyticus',
#  'gordonia sp. hy186',
#  'escherichia sp. sflu5',
#  'dickeya virus rc2014',
#  'betacoronavirus 1',
#  'lactococcus virus ascc191',
#  'methylobacterium sp. ni91',
#  'acinetobacter sp. sun',
#  'aeromonas virus aeh1',
#  'rickettsia australis',
#  'serratia virus bf',
#  'sphingomonas sp. hdw15b',
#  'pseudomonas virus henninger',
#  'desulfohalobium retbaense',
#  'tomato chlorotic leaf distortion virus',
#  'mycoplasma mobile',
#  'potosi orthobunyavirus',
#  'bacillus virus 1',
#  'bat mastadenovirus d',
#  'mycoplasma bovirhinis',
#  'prevotella scopos',
#  'fimbriimonas ginsengisoli',
#  'mycobacterium virus acadian',
#  'shigella virus sb1',
#  'bernardetia litoralis',
#  'alstroemeria yellow spot orthotospovirus',
#  'klebsiella virus sugarland',
#  'escherichia virus su10',
#  'bacillus freudenreichii',
#  'bartonella australis',
#  'vibrio virus kvp40',
#  'pseudomonas virus cebdp1',
#  'pseudomonas sabulinigri',
#  'twisted-stalk chlorotic streak virus',
#  'aeromonas phage lah9',
#  'mycoplasma bovigenitalium',
#  'sulfurimonas sp. gysz_1',
#  'halomonas sp. zm3',
#  'escherichia virus c40',
#  'saccharomonospora azurea',
#  'mycoplasma synoviae',
#  'erwinia virus machina',
#  'staphylococcus virus p108',
#  'dengue virus',
#  'citrobacter sp. rhbstw-00446',
#  'achromobacter sp. lm16',
#  'parvularcula bermudensis',
#  'citrobacter freundii complex sp. cfnih9',
#  'shigella virus sfph2',
#  'pseudomonas virus ab05',
#  'cronobacter virus cr8',
#  'opitutus terrae',
#  'shewanella denitrificans',
#  'nonomuraea nitratireducens',
#  'mycoplasma arginini',
#  'nocardioides sp. hy056',
#  'corynebacterium sp. zg-320',
#  'aeromonas sp.',
#  'gammapapillomavirus 10',
#  'klebsiella virus ime260',
#  'salmonella virus sp6',
#  'congregibacter litoralis',
#  'rahnella sp. wmr121',
#  'rahnella sp. wmr120',
#  'corynebacterium virus darwin',
#  'citrobacter virus moogle',
#  'erythrobacter sp. 6d36',
#  'acinetobacter virus aci08',
#  'salmonella virus nr01',
#  'mycobacterium virus pukovnik',
#  'arthrobacter virus colucci',
#  'pectinobacterium virus cbb',
#  'lactobacillus virus iacchus',
#  'synechococcus virus srim44',
#  'streptomyces roseochromogenus',
#  'streptomyces sp. hk1',
#  'escherichia virus hy03',
#  'ammonifex degensii',
#  'gammapapillomavirus 14',
#  'bacillaceae bacterium jmak1',
#  'lactobacillus virus semele',
#  'klebsiella virus kp2',
#  'aeromonas phage 4_l372d',
#  'acinetobacter sp. m131',
#  'shewanella amazonensis',
#  'mycobacterium virus solon',
#  'clostridium sp. mcf-1',
#  'octadecabacter arcticus',
#  'actinomyces sp. zj34',
#  'spirosoma sp. cju-r4',
#  'mycobacterium virus twister',
#  'citrobacter sp. rhbstw-00848',
#  'vibrio sp. 04ya108',
#  'marinobacter hydrocarbonoclasticus',
#  'corynebacterium sphenisci',
#  'desulfovibrio marinus',
#  'ateline gammaherpesvirus 2',
#  'streptococcus virus 2972',
#  'erwinia piriflorinigrans',
#  'bacteroides sp. hf-5141',
#  'pseudomonas virus dl60',
#  'streptomyces phage wofford',
#  'rickettsia sibirica',
#  'mycoplasma anatis',
#  'corynebacterium sp. nml93-0612',
#  'streptomyces virus zemlya',
#  'streptomyces cattleya',
#  'pelagibacter virus htvc019p',
#  'sinorhizobium sp. lm21',
#  'koongol orthobunyavirus',
#  'pseudomonas denitrificans (nom. rej.)',
#  'streptomyces asterosporus',
#  'caldicellulosiruptor owensensis',
#  'gordonia virus brutongaster',
#  'heliobacterium modesticaldum',
#  'planococcus sp. zoym',
#  'nostoc carneum',
#  'hepatovirus b',
#  'alkalihalobacillus halodurans',
#  'neorickettsia sennetsu',
#  'alphapapillomavirus 8',
#  'corynebacterium choanis',
#  'escherichia virus vpae1',
#  'simian mastadenovirus a',
#  'enseada orthobunyavirus',
#  'escherichia virus ime11',
#  'pestivirus g',
#  "anaerolinea sp. 'rifampicinis'",
#  'pseudomonas virus pa8p1',
#  'mycobacterium virus heldan',
#  'anaerolinea thermophila',
#  'bacillus virus bm15',
#  'capim orthobunyavirus',
#  'bovine torovirus',
#  'gordonia virus oneup',
#  'salmonella virus setp3',
#  'thermomicrobium roseum',
#  'methylococcus sp. im1',
#  'vibrio virus nt1',
#  'sulfurihydrogenibium sp. yo3aop1',
#  'caulobacter virus ccrbl9',
#  'pseudomonas virus m6',
#  'gordonia virus vivi2',
#  'methylacidiphilum infernorum',
#  'zalophus californianus polyomavirus 1',
#  'wolkberg orthobunyavirus',
#  'propionibacterium virus phl009m11',
#  'klebsiella virus kpv41',
#  'staphylococcus virus s25-4',
#  'synechococcus virus srim50',
#  'lactococcus virus c2',
#  'rickettsia slovaca',
#  'mycobacterium virus jamal',
#  'gemmobacter sp. hyn0069',
#  'pseudomonas virus pa7',
#  'mycobacterium virus omega',
#  'morreton vesiculovirus',
#  'hyphomicrobium nitrativorans',
#  'choristoneura rosaceana entomopoxvirus',
#  'escherichia virus wv8',
#  'prevotella sp. wr041',
#  'cyanobacterium aponinum',
#  'shigella virus 008',
#  'ochrobactrum sp. mt180101',
#  'escherichia virus apec7',
#  'klebsiella virus kpv71',
#  'altererythrobacter atlanticus',
#  'alphapapillomavirus 6',
#  'acaryochloris marina',
#  'desulfosarcina ovata',
#  'labrenzia sp. thaf187b',
#  'acinetobacter sp.',
#  'abyssogena phaseoliformis symbiont',
#  'micromonas pusilla virus sp1',
#  'advenella mimigardefordensis',
#  'olsenella umbonata',
#  'mycolicibacterium doricum',
#  'erwinia virus yoloswag',
#  'microplitis demolitor bracovirus',
#  'alphapapillomavirus 11',
#  'sphingomonas sp. a1',
#  'caulobacter virus swift',
#  'mycoplasma orale',
#  'labrenzia alexandrii',
#  'mycobacterium virus bane1',
#  'leuconostoc gelidum',
#  'klebsiella phage jy917',
#  'enterococcus virus ly0322',
#  'haloactinobacterium sp. hy164',
#  'gloeobacter violaceus',
#  'corynebacterium doosanense',
#  'desulfovibrio carbinoliphilus',
#  'arthrobacter virus wayne',
#  'rubrobacter sp. scsio 52915',
#  'civet circovirus',
#  'echinicola vietnamensis',
#  'escherichia virus js98',
#  'mycoplasma cloacale',
#  'pectobacterium virus pp16',
#  'tomitella sp. hy188',
#  'legionella fallonii',
#  'mycobacterium virus gladiator',
#  'enterobacter sp. 638',
#  'dickeya virus bf25-12',
#  'escherichia virus ba14',
#  'burkholderia sp. kk1',
#  'sporosarcina sp.',
#  'roseiflexus castenholzii',
#  'rickettsia canadensis',
#  'burkholderia sp. the68',
#  'runella sp. hyn0085',
#  'brassica campestris chrysovirus',
#  'banana streak virus',
#  'syntrophus aciditrophicus',
#  'anaplasma centrale',
#  'pseudomonas virus ab18',
#  'bacillus virus finn',
#  'streptomyces sp. 44030',
#  'simian mastadenovirus d',
#  'human mastadenovirus g',
#  'xylella virus salvo',
#  'flavobacterium virus fcv1',
#  'shigella virus shsml521',
#  'heliothis zea nudivirus',
#  'shewanella sp. fjat-53720',
#  'mycoplasma gallinaceum',
#  'nitrosococcus watsonii',
#  'human polyomavirus 4',
#  'lactobacillus virus maenad',
#  'cafeteria roenbergensis virus',
#  'caulobacter virus phicbk',
#  'halovirus hrtv-7',
#  'xanthomonas virus f30',
#  'roseobacter phage rd-1410w1-01',
#  'arthrobacter virus bridgette',
#  'klebsiella virus jd18',
#  'salinicoccus sp.',
#  'murid betaherpesvirus 2',
#  'candidatus mycoplasma haemolamae',
#  'synechococcus sp. utex 2973',
#  'spiroplasma floricola',
#  'tanapox virus',
#  'marinomonas mediterranea',
#  'sulfitobacter sp. dfl14',
#  'propionibacterium virus phl114l00',
#  'roseomonas sp. 1318',
#  'propionibacterium virus phl179m00',
#  'citrobacter sp. rhbstw-00137',
#  'kairi orthobunyavirus',
#  'selenomonas sp. marseille-q3039',
#  'acinetobacter virus ap22',
#  'spirosoma sp. pl0136',
#  'chlorobaculum tepidum',
#  'chroococcidiopsis thermalis',
#  'nakamurella sp. s14-144',
#  'mycoplasma sp. c264-nas',
#  'clostridium sp. mt351',
#  'nocardioides sp. dk3136',
#  'bacillus virus avesobmore',
#  'escherichia virus e112',
#  'chloroherpeton thalassium',
#  'klebsiella virus su503',
#  'pseudomonas virus pamx74',
#  'gammapapillomavirus 1',
#  'escherichia virus esco5',
#  'flavobacterium virus 2a',
#  'leclercia sp.',
#  'marivivens sp. jlt3646',
#  'escherichia virus vr7',
#  'tataguine orthobunyavirus',
#  'pseudomonas sp. tum18999',
#  'vibrio virus vp882',
#  'bacillus sp. #24',
#  'pseudomonas virus 130-113',
#  'mycoplasma pneumoniae',
#  'klebsiella virus f19',
#  'lactococcus virus ascc465',
#  'escherichia virus st32',
#  'eggerthella sp. hf-1101',
#  'gordonia virus suzy',
#  'klebsiella virus matisse',
#  'gammapapillomavirus 3',
#  'bacillus virus bcp1',
#  'bat mastadenovirus e',
#  'human polyomavirus 11',
#  'propionibacterium virus p1001',
#  'nl63-related bat coronavirus strain btkynl63-9b',
#  'bacillus virus agate',
#  'pseudomonas virus ibbpf7a',
#  'sulfurimonas sp. nw10',
#  'shewanella sp. 33b',
#  'mycoplasma dispar',
#  'mycoplasma hominis',
#  'staphylococcus virus sep1',
#  'gammapapillomavirus 2',
#  'nostoc piscinale',
#  'enterobacter virus ecpyzu01',
#  'simian adenovirus b',
#  'sulfolobus islandicus rod-shaped virus 9',
#  'pseudoarcobacter acticola',
#  'streptomyces olivoreticuli',
#  'thermus sp. 4c',
#  'cycloclasticus zancles',
#  'desulfurivibrio alkaliphilus',
#  'arthrobacter virus piccoletto',
#  'escherichia virus k1g',
#  'bythopirellula goksoyri',
#  'mahella australiensis',
#  'streptomyces virus lika',
#  'pseudomonas virus lana',
#  'deer atadenovirus a',
#  'propionibacterium virus mrak',
#  'frankia sp. ean1pec',
#  'mycoplasma hyopneumoniae',
#  'pseudoalteromonas virus c5a',
#  'nitrosococcus halophilus',
#  'porphyromonas asaccharolytica',
#  'shigella virus a7',
#  'bacillus virus cp51',
#  'mycoplasma leachii',
#  'methylobacterium sp. ams5',
#  'sphingomonas sp. yz-8',
#  'gemmatirosa kalamazoonesis',
#  'leptospirillum ferrooxidans',
#  'porcine mastadenovirus a',
#  'synechococcus virus bellamy',
#  'citrobacter sp. rhbstw-00053',
#  'enterococcus virus ecp3',
#  'escherichia virus hk633',
#  'salmonella virus 3a8767',
#  'colwellia beringensis',
#  'micrococcus sp. v7',
#  'cellulosimicrobium sp. bi34t',
#  'lactococcus virus sl4',
#  'hibbertia virus y',
#  'mycobacterium virus trixie',
#  'shigella virus pss1',
#  'staphylococcus virus g1',
#  'granulicella tundricola',
#  'sulfolobus islandicus rod-shaped virus 11',
#  'musca hytrosavirus',
#  'harvey murine sarcoma virus',
#  'streptomyces sviceus',
#  'chlamydia sp. s15-834c',
#  'dinoroseobacter phage ds-1410ws-06',
#  'shigella virus sp18',
#  'erwinia virus desertfox',
#  'paucilactobacillus oligofermentans',
#  'acinetobacter virus wchabp1',
#  'bacillus sp. dsl-17',
#  'moraxella sp. ta144',
#  'cronobacter universalis',
#  'bacillus cellulosilyticus',
#  'ralstonia virus rsl1',
#  'cachoeira porteira orthobunyavirus',
#  'geobacillus sp. y4.1mc1',
#  'shewanella sp. ylb-06',
#  'bacillus sp. v3',
#  'rickettsia sp. tillamook 23',
#  'klebsiella virus kps2',
#  'sinorhizobium sp. m14',
#  'gordonia virus lennon',
#  'geobacter bremensis',
#  'chelativorans sp. bnc1',
#  'euzebya sp. dy32-46',
#  'acinetobacter virus ab3',
#  'murine coronavirus',
#  'proteus virus isfahan',
#  'rhodococcus virus pepy6',
#  'pseudomonas virus phikz',
#  'arthrobacter virus circum',
#  'henbane mosaic virus',
#  'american bat vesiculovirus',
#  'mycobacterium virus dandelion',
#  'lactococcus virus p008',
#  'hydrogenobacter thermophilus',
#  'lactococcus virus ascc281',
#  'escherichia virus ar1',
#  'mycobacterium virus crimd',
#  'acholeplasma axanthum',
#  'mycoplasma neurolyticum',
#  'actinomyces sp. zj750',
#  'escherichia virus dt57c',
#  'mycobacterium virus vincenzo',
#  'pseudomonas virus pap3',
#  'staphylococcus sp. 693-2',
#  'pelagivirus s35c6',
#  'synechococcus virus smbcm100',
#  'streptomyces virus sujidade',
#  'sulfolobus islandicus rod-shaped virus 4',
#  'pseudomonas virus pf10',
#  'micrococcus sp. a7',
#  'lactobacillus virus nyseid',
#  'cyanobacterium endosymbiont of epithemia turgida',
#  'vibrio sp. sal10',
#  'wolbachia endosymbiont of onchocerca volvulus',
#  'pectobacterium virus phoria',
#  'mycoplasma alkalescens',
#  'escherichia virus phapec2',
#  'simian mastadenovirus e',
#  'escherichia virus rtp',
#  'terriglobus saanensis',
#  'anthurium mosaic-associated chrysovirus',
#  'escherichia virus schickermooser',
#  'salmonella virus sp01',
#  'streptomyces sp. x3',
#  'propionibacterium virus ouroboros',
#  'jonquetella anthropi',
#  'hyphomicrobium denitrificans',
#  'brochothrix virus a9',
#  'staphylococcus virus bs1',
#  'achromobacter virus jwalpha',
#  'mycobacterium sp. qia-37',
#  'sphaerobacter thermophilus',
#  'streptomyces virus darolandstone',
#  'corynebacterium sp. zg-917',
#  'mycobacterium virus cooper',
#  'sida golden mosaic braco virus',
#  'streptomyces sp. z022',
#  'methylobacterium sp. dm1',
#  'geobacillus sp. 610',
#  'planococcus sp. (in: bacteria)',
#  'anhembi orthobunyavirus',
#  'geobacillus sp. y412mc61',
#  'cercopithecus erythrotis polyomavirus 1',
#  'escherichia virus phieco32',
#  'rickettsia africae',
#  'acinetobacter virus as11',
#  'mycobacterium virus littlee',
#  'pseudomonas virus ps44',
#  'pseudomonas sp. ct14',
#  'pseudomonas virus chu',
#  'lactococcus phage p335 sensu lato',
#  'magnetospirillum magneticum',
#  'mycoplasma iowae',
#  'mycobacterium virus bask21',
#  'gammapapillomavirus 27',
#  'staphylococcus virus ipla7',
#  'shigella virus sf21',
#  'spiroplasma diminutum',
#  'pseudomonas sp. s211(2017)',
#  'hoyosella subflava',
#  'citrobacter sp. 36-4cpa',
#  'escherichia virus murica',
#  'klebsiella virus jd001',
#  'bacillus sp. ihb b 7164',
#  'salmonella virus felixo1',
#  'acinetobacter virus lz35',
#  'rousettus bat coronavirus gccdc1',
#  'mycoplasma arthritidis',
#  'mycobacterium virus rumpelstiltskin',
#  'escherichia virus ime18',
#  'bacillus sp. m4u3p1',
#  'alphaproteobacteria virus phijl001',
#  'escherichia virus hz2r8',
#  'neorickettsia helminthoeca',
#  'staphylococcus virus ph15',
#  'streptacidiphilus bronchialis',
#  'jamestown canyon orthobunyavirus',
#  'corynebacterium maris',
#  'barnesiella viscericola',
#  'mycobacterium virus toto',
#  'ornithinimicrobium sp. h23m54',
#  'escherichia virus fv3',
#  'xanthomonas virus xaj24',
#  'corynebacterium sp. zj-599',
#  'mycoplasma flocculare',
#  'borrelia recurrentis',
#  'enterococcus virus al3',
#  'acinetobacter virus ab1',
#  'melao orthobunyavirus',
#  'dehalogenimonas lykanthroporepellens',
#  'staphylococcus virus slpw',
#  'thermoanaerobacter brockii',
#  'citrobacter virus sh4',
#  'vibrio sp. 09022',
#  'humibacter sp. wj7-1',
#  'erwinia virus eah2',
#  'saccharomonospora marina',
#  'tomato spotted wilt tospovirus',
#  'polar bear mastadenovirus 1',
#  'mycobacterium phage jolie1',
#  'yersinia virus yeo3-12',
#  'truepera radiovictrix',
#  'echinicola sp. ln3s3',
#  'acinetobacter virus aci01-1',
#  'bacillus sp. jamb750',
#  'mycolicibacterium sp. lj126',
#  'enterococcus virus auef3',
#  'ilesha orthobunyavirus',
#  'bacillus virus taylor',
#  'chrysanthemum stem necrosis orthotospovirus',
#  'serratia virus sm9-3y',
#  'campylobacter virus cp81',
#  'escherichia virus rb3',
#  'mycobacterium virus fionnbarth',
#  'bacillus sp. hd4p25',
#  'phormidium virus wmp3',
#  'ornithinimicrobium sp. ama3305',
#  'clostridium cellulovorans',
#  'bacillus virus glittering',
#  'sweet potato mild speckling virus',
#  'oriboca orthobunyavirus',
#  'francisella persica',
#  'methylobacterium nodulans',
#  'skunk mastadenovirus a',
#  'propionibacterium virus p1.1',
#  'spiroplasma sabaudiense',
#  'vibrio virus valkk3',
#  'planococcus dechangensis',
#  'pseudomonas virus bjorn',
#  'phocid alphaherpesvirus 1',
#  'thermoanaerobacter wiegelii',
#  'treponema primitia',
#  'mycobacterium phage adler',
#  'yersinia virus pst',
#  'batai orthobunyavirus',
#  'bat associated circovirus 4',
#  'vibrio sp. 23023',
#  'mycolicibacterium goodii',
#  'simian mastadenovirus f',
#  'elusimicrobium minutum',
#  'escherichia virus slur03',
#  'propionibacterium virus p91',
#  'agromyces sp. kacc 19306',
#  'thermoanaerobacter sp. x513',
#  'muriicola sp. mms17-sy002',
#  'sulfurospirillum barnesii',
#  'desulfobacter postgatei',
#  'tepidanaerobacter acetatoxydans',
#  'acinetobacter phage lazarus',
#  'mycobacterium virus violet',
#  'moumouvirus',
#  'marichromatium purpuratum',
#  'streptomyces sp. crxt-y-14',
#  'propionibacterium virus phl095n00',
#  'sulfurimonas gotlandica',
#  'desulfovibrio vulgaris',
#  'lactobacillus virus p1',
#  'mycoplasma sp. phocoena c-264-gen',
#  'desulfomicrobium orale',
#  'streptomyces bingchenggensis',
#  'propionibacterium virus pad20',
#  'halomonas sp. ant2',
#  'streptomyces natalensis',
#  'aino orthobunyavirus',
#  'porcine type-c oncovirus',
#  'salmonella virus s131',
#  'staphylococcus virus psa3',
#  'shigella sp. mo17',
#  'rhodobacter virus rctitan',
#  'mycobacterium virus lhtscc',
#  'pseudomonas virus pap1',
#  'bifidobacterium actinocoloniiforme',
#  'mycobacterium virus yoshi',
#  'shewanella pealeana',
#  'porcine associated gemycircularvirus 1',
#  'synechococcus sp. a18-40',
#  'escherichia virus hk578',
#  'pestivirus b',
#  'cronobacter virus gap31',
#  'keystone orthobunyavirus',
#  'citrobacter sp. rhbstw-00887',
#  'bat mastadenovirus b',
#  'confluentimicrobium sp. emb200-ns6',
#  'ranunculus leaf distortion virus',
#  'corynebacterium nuruki',
#  'mycobacterium virus che9d',
#  'serpentinomonas mccroryi',
#  'halomonas sp. bc-m4-5',
#  'lumpy skin disease virus',
#  'arthrobacter virus constance',
#  'burkholderia virus bcep781',
#  'bacillus virus andromeda',
#  'escherichia virus js09',
#  'mycobacterium gallinarum',
#  'citrobacter sp. rhbstw-00976',
#  'acinetobacter virus aci02-2',
#  'escherichia virus 64795ec1',
#  'microbacterium virus hyperion',
#  'pseudomonas virus ab26',
#  'sphingomonas sp. lmo-1',
#  'weissella sp. hdw19',
#  'synechococcus virus ac2014fsyn7803c8',
#  'bacillus virus phi29',
#  'vibrio tapetis',
#  'burkholderia sp. m701',
#  'myxococcus virus mx8',
#  'salmonella virus fsl sp-058',
#  'salmonella virus stp4a',
#  'yug bogdanovac vesiculovirus',
#  'mycoplasma canis',
#  'corynebacterium aquilae',
#  'sphingomonas sanxanigenens',
#  'mycoplasma salivarium',
#  'afipia carboxidovorans',
#  'clavibacter sp. dm1',
#  'xanthomonas virus xc10',
#  'pestivirus c',
#  'ilumatobacter coccineus',
#  'treponema paraluiscuniculi',
#  'sphingomonas sp. cra20',
#  'aurantimicrobium sp. mwh-mo1',
#  'murine leukemia-related retroviruses',
#  'bacillus ciccensis',
#  'salmonella virus bps17w1',
#  'mycoplasma parvum',
#  'pseudomonas sp. lm8',
#  'mycobacterium virus athena',
#  'bacillus virus bigbertha',
#  'pseudomonas sp. zm1',
#  'salmonella virus skml39',
#  'hardy-zuckerman feline sarcoma virus',
#  'acinetobacter phage kimel',
#  'bacillus virus ga1',
#  'leclercia virus 10164-302',
#  'enterobacter sp. 247',
#  'caldicellulosiruptor kronotskyensis',
#  'legionella sp. tum19329',
#  'crassocephalum yellow vein virus',
#  'desulfococcus oleovorans',
#  'bacillus phage bcja1c',
#  'pestivirus h',
#  'sango orthobunyavirus',
#  'thermodesulfobacterium geofontis',
#  'klebsiella phage knp2',
#  'alphapapillomavirus 9',
#  'bacillus virus bp8pc',
#  'bacillus virus bcp82',
#  'pectobacterium virus ppws2',
#  'sanguibacter keddieii',
#  'prochlorococcus virus med4-213',
#  'simian mastadenovirus i',
#  'burkholderia sp. yi23',
#  'yersinia virus ypspg',
#  'corynebacterium sp. l2-79-05',
#  'prevotella fusca',
#  'propionibacterium virus phl092m00',
#  'rhodospirillum centenum',
#  'rickettsia heilongjiangensis',
#  'exiguobacterium arabatum',
#  'melioribacter roseus',
#  'fusobacterium sp. nsj-57',
#  'streptomyces sp. crpj-33',
#  'leuconostoc virus 1a4',
#  'klebsiella virus kox1',
#  'sulfurospirillum halorespirans',
#  'staphylococcus virus sextaec',
#  'salmonella virus sp101',
#  'mycoplasma bovis',
#  'propionibacterium virus lauchelly',
#  'pseudomonas sp. snu wt1',
#  'ralstonia virus rsl2',
#  'tolumonas auensis',
#  'mycoplasma glycophilum',
#  'mycoplasma canadense',
#  'streptomyces sp. w9',
#  'algicoccus marinus',
#  'orbus sp. ipmb12',
#  'bovine alphaherpesvirus 1',
#  'staphylococcus virus csa13',
#  'pseudomonas virus pamx11',
#  'pseudomonas sp. r2a2',
#  'simiduia agarivorans',
#  'streptomyces virus lannister',
#  'microbacterium sp. a18jl200',
#  'bacillus sp. pamc26568',
#  'invertebrate iridescent virus 9',
#  'prevotella dentalis',
#  'bacillus virus blastoid',
#  'treponema sp. rcc2812',
#  'halorubrum phage cgphi46',
#  'brevicoryne brassicae virus',
#  'aeromonas virus ahszw1',
#  'streptomyces virus paradiddles',
#  'leanyer orthobunyavirus',
#  'pseudomonas sp. s1-a32-2',
#  'gottschalkia acidurici',
#  'cocal vesiculovirus',
#  'flavobacterium virus fcl2',
#  'pseudomonas virus kpp12',
#  'schnuerera ultunensis',
#  'eubacterium sp. nsj-61',
#  'sphingomonas sp. mk52',
#  'macacine betaherpesvirus 9',
#  'salmonella virus sse121',
#  'mycobacterium virus bxz1',
#  'lactococcus virus 712',
#  'ralstonia virus rsf1',
#  '[eubacterium] cellulosolvens',
#  'micrococcus sp. a1',
#  'escherichia virus t7',
#  'sphingomonas sp. je1',
#  'flavihumibacter sp. sb-02',
#  'bat mastadenovirus a',
#  'propionibacterium virus solid',
#  'equine mastadenovirus b',
#  'corynebacterium sp. 1864',
#  'propionibacterium virus phl141n00',
#  'gammapapillomavirus 26',
#  'synechococcus virus ssm1',
#  'anopheles a orthobunyavirus',
#  'arthrobacter virus martha',
#  'pseudomonas virus luz19',
#  'veillonella sp. ok1',
#  'watermelon bud necrosis tospovirus',
#  'caldicellulosiruptor hydrothermalis',
#  'human endogenous retrovirus k',
#  'roseovarius plymouth podovirus 1',
#  'erwinia virus deimos',
#  'dinoroseobacter virus dfl12',
#  'streptomyces sp. crxt-g-22',
#  'campylobacter virus cpx',
#  'treponema azotonutricium',
#  'cellulophaga virus cba172',
#  'staphylococcus virus 66',
#  'bacillus virus bc431',
#  'bacillus sporothermodurans',
#  'staphylococcus sp. cdc25',
#  'propionibacterium virus phl070n00',
#  'chlamydia felis',
#  'synechococcus virus scam9',
#  'mycobacterium virus stinger',
#  'mycobacterium virus ericb',
#  'pseudomonas virus 17a',
#  'enterococcus virus eczz2',
#  'mycobacterium virus baee',
#  'mycobacterium virus timshel',
#  'methylibium petroleiphilum',
#  'pseudomonas virus lko4',
#  'dolichospermum compactum',
#  'rahnella sp. wmr114',
#  'salmonella virus 123',
#  'bat coronavirus cdphe15',
#  'escherichia virus pbeco4',
#  'nocardioides sp. mc1495',
#  'streptomyces sp. fq1',
#  'niabella soli',
#  'treponema socranskii',
#  'enterococcus virus efacpt1',
#  'escherichia virus wg01',
#  'agrobacterium genomosp. 6',
#  'oxynema sp. ap17',
#  'escherichia virus k1ind2',
#  'mycobacterium virus macncheese',
#  'escherichia virus hy01',
#  'impatiens necrotic spot tospovirus',
#  'enterobacter sp. r4-368',
#  'severe acute respiratory syndrome-related coronavirus',
#  'pectobacterium virus ppws1',
#  'geobacillus virus tp84',
#  'bacillus marisflavi',
#  'pseudomonas virus 22pflur64pp',
#  'exiguobacterium sp. s3-2',
#  'mycobacterium virus sbash',
#  'sulfurimonas denitrificans',
#  'koutango virus',
#  'thiocystis violascens',
#  'sulfitobacter pseudonitzschiae',
#  'pseudomonas xinjiangensis',
#  'gordonia virus vendetta',
#  'arthrobacter virus joann',
#  'enterovirus l',
#  'escherichia virus eg1',
#  'maridesulfovibrio salexigens',
#  'escherichia virus mx01',
#  'lactococcus virus sk1',
#  'syntrophotalea carbinolica',
#  'escherichia virus min27',
#  'alagoas vesiculovirus',
#  'bacteroides sp. hf-5287',
#  'aeromonas virus aes12',
#  'staphylococcus phage sa1',
#  'treponema sp. omz 804',
#  'pseudomonas sp. s-6-2',
#  'listeria virus ag20',
#  'corynebacterium geronticis',
#  'lactobacillus virus lenus',
#  'bacillus sp. tk-2',
#  'nocardioides dokdonensis',
#  'pseudopedobacter saltans',
#  'micromonospora sp. 28isp2-46',
#  'mycobacterium virus mozy',
#  'mycoplasma hyorhinis',
#  'myotis lucifugus polyomavirus 1',
#  'lactococcus virus cb13',
#  'gammapapillomavirus 17',
#  'yellowstone lake mimivirus',
#  'escherichia virus jenp2',
#  'propionibacterium virus procrass1',
#  'raineyella sp. cba3103',
#  'klebsiella virus bo1e',
#  'rhodobacter blasticus',
#  'alphapapillomavirus 1',
#  'erwinia virus alexandra',
#  'propionibacterium virus phl308m00',
#  'basilea psittacipulmonis',
#  'shigella virus sf22',
#  'escherichia virus gj1',
#  'klebsiella virus kpv52',
#  'chlorobaculum parvum',
#  'escherichia virus ecml134',
#  'xanthomonas virus f20',
#  'crassaminicella sp. sy095',
#  'fluviicola taffensis',
#  'sulfurihydrogenibium azorense',
#  'chlorocebus pygerythrus polyomavirus 2',
#  'platyrrhini mastadenovirus a',
#  'pontivivens sp. mt2928',
#  'escherichia virus ecbp1',
#  'mycobacterium virus saintus',
#  'mycobacterium virus soto',
#  'mycobacterium virus rosebush',
#  'planococcus sp. y42',
#  'mycoplasma phocidae',
#  'caulobacter virus ccrsc',
#  'synechococcus sp. rs9915',
#  'synechococcus sp. a15-24',
#  'runella slithyformis',
#  'caldicellulosiruptor sp. ya01',
#  'acinetobacter virus 133',
#  'roseococcus sp. nibr12',
#  'labrenzia sp. thaf35',
#  'hepatovirus e',
#  'geobacillus sp. wch70',
#  'salmonella virus uab87',
#  'pestivirus a',
#  'saccharomonospora cyanea',
#  'angelica virus y',
#  'mycoplasma haemofelis',
#  'thermaerobacter marianensis',
#  'cronobacter virus gap32',
#  'propionibacterium virus pirate',
#  'pseudomonas virus sl2',
#  'dolichospermum flos-aquae',
#  'streptomyces sp. f2',
#  'psittacine atadenovirus a',
#  'strepomyces virus drgrey',
#  ...]

# %%
results["eubacterium limosum"]
# Out:
# [('atcc 8486',
#   'https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/807/675/GCF_000807675.2_ASM80767v2'),
#  ('sa11',
#   'https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/001/481/725/GCF_001481725.1_ASM148172v1'),
#  ('8486cho',
#   'https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/003/182/515/GCF_003182515.1_ASM318251v1'),
#  ('dfi.6.107',
#   'https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/020/559/625/GCF_020559625.1_ASM2055962v1'),
#  ('b2',
#   'https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/023/520/755/GCF_023520755.1_ASM2352075v1'),
#  ('',
#   'https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/900/683/775/GCF_900683775.1_ASM90068377v1')]

# %% [markdown]
# **Download the microbial reference genome (fna & gff) based on the query**

# %% [markdown]
# Shell file output

# %%
microbe_rg.download_ref_genome("../raw/RefSeq/Micro+Virus/", dir_shell_output="../raw/RefSeq/download_shell_scripts/", as_shell_file=True)
